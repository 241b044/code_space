# %% [markdown]
# <a href="https://colab.research.google.com/github/241b044/code_space/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

distances, previous = dijkstra(graph, 'A')

for node in distances:
    print("Distance from A to", node, "=", distances[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}
    visited = []

    distances[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor] = min_node

    return distances, previous

# %%
def get_path(previous, start, end):
    path = []
    current = end

    while current:
        path.insert(0, current)
        current = previous[current]

    return path if path[0] == start else []

# %%
graph = {}

n = int(input("Enter number of nodes: "))
for _ in range(n):
    node = input("Enter node name: ")
    graph[node] = {}

    m = int(input(f"Enter number of neighbors for {node}: "))
    for _ in range(m):
        neighbor = input("  Neighbor: ")
        weight = int(input("  Weight: "))
        graph[node][neighbor] = weight
# Out:
# Enter number of nodes: 4
# Enter node name: A
# Enter number of neighbors for A: 2
#   Neighbor: B
#   Weight: 4
#   Neighbor: C
#   Weight: 2
# Enter node name: C
# Enter number of neighbors for C: 3
#   Neighbor: A
#   Weight: 4
#   Neighbor: C
#   Weight: 5
#   Neighbor: D
#   Weight: 10
# Enter node name: C
# Enter number of neighbors for C: 3
#   Neighbor: A
#   Weight: 2
#   Neighbor: B
#   Weight: 5
#   Neighbor: D
#   Weight: 3
# Enter node name: D
# Enter number of neighbors for D: 2
#   Neighbor: B
#   Weight: 10
#   Neighbor: C
#   Weight: 3

# %%
print("\nAdd 2 more nodes:")
for _ in range(2):
    node = input("Enter new node name: ")
    graph[node] = {}

    m = int(input(f"Enter number of neighbors for {node}: "))
    for _ in range(m):
        neighbor = input("  Neighbor: ")
        weight = int(input("  Weight: "))
        graph[node][neighbor] = weight
# Out:
# Add 2 more nodes:
# Enter new node name: E
# Enter number of neighbors for E: 2
#   Neighbor: F
#   Weight: 4
#   Neighbor: D
#   Weight: 6
# Enter new node name: F
# Enter number of neighbors for F: 2
#   Neighbor: D
#   Weight: 5
#   Neighbor: E
#   Weight: 4

# %%
from ast import Break
while True:
    start = input("\nEnter source node (or 'exit' to stop): ")
    if start.lower() == 'exit':
        break

    if start not in graph:
        print("Invalid source node!")
        break

    distances, previous = dijkstra(graph, start)

    print(f"\nShortest paths from {start}:")
    for node in graph:
        path = get_path(previous, start, node)
        if distances[node] == float('inf'):
            print(f"{node}: No path")
        else:
            print(f"{node}: Distance = {distances[node]}, Path = {' -> '.join(path)}")
# Out:
# Enter source node (or 'exit' to stop): A
#
# Shortest paths from A:
# A: Distance = 0, Path = A
# B: Distance = 4, Path = A -> B
# C: Distance = 2, Path = A -> C
# D: Distance = 5, Path = A -> C -> D
#
# Enter source node (or 'exit' to stop): H
# Invalid source node!
